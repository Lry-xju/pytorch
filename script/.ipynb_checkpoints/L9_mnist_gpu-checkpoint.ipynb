# %%
import torch 
in_channels ,out_channels =5,10
width ,height =100,100
kernel_size = 3
batchsize = 1#32
input = torch.randn(batchsize,in_channels,width,height)
conv_layer = torch.nn.Conv2d(in_channels,out_channels,kernel_size=kernel_size,padding=1)
output = conv_layer(input)
print(input.shape)
print(output.shape)
print(conv_layer.weight.shape)
# Out:
# torch.Size([1, 5, 100, 100])
# torch.Size([1, 10, 100, 100])
# torch.Size([10, 5, 3, 3])

# %%
import torch 
input = [3,4,6,5,7,2,4,6,8,2,1,6,7,8,4,9,7,4,6,2,3,7,5,4,1]
input = torch.Tensor(input).view(1,1,5,5) # B,C,W H
conv_layer = torch.nn.Conv2d(1,1,kernel_size=kernel_size,padding=1,stride=2,bias = False)
sampling_layer = torch.nn.MaxPool2d(kernel_size= 2)
kernel = torch.Tensor([1,2,3,4,5,6,7,8,9]).view(1,1,3,3) # out_channel,input_channel,W,H
conv_layer.weight.data = kernel.data
output = conv_layer(input)
#output = sampling_layer(output)
print(input.shape)
print(output)
print(conv_layer.weight.shape)
# Out:
# torch.Size([1, 1, 5, 5])
# tensor([[[[ 91., 224., 127.],
#           [192., 282., 122.],
#           [ 96., 110.,  31.]]]], grad_fn=<ConvolutionBackward0>)
# torch.Size([1, 1, 3, 3])

# %%
import torch
from torchvision import transforms
from torchvision import datasets
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.nn.functional as F
import numpy as np

# %%
import torchvision
batch_size = 64
transform  = transforms.Compose([
    transforms.ToTensor(), #convert pil image to tensor
    transforms.Normalize((0.1307,),( 0.3081,)) # mean & std,数字是对mnist计算出的经验值
])
train_dataset = datasets.MNIST(root='../dataset/mnist',train = True,transform=transform,download = True)
test_dataset = datasets.MNIST(root='../dataset/mnist',train = False,transform=transform,download = True)
train_loader = DataLoader(dataset= train_dataset,batch_size= batch_size ,shuffle= True)
test_loader = DataLoader(dataset= test_dataset,batch_size= batch_size ,shuffle= False)

# %%
class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv_layer1 = torch.nn.Conv2d(1,10,kernel_size=5,padding=0,stride=1,bias = False)
        self.conv_layer2 = torch.nn.Conv2d(10,20,kernel_size=5,padding=0,stride=1,bias = False)
        self.maxPooling_layer = torch.nn.MaxPool2d(kernel_size= 2)
        self.fc = torch.nn.Linear(320,10)

    def forward(self, x):
        batch_size = x.size(0)
        x = self.conv_layer1 (x)
        # print(x.shape)
        x = F.relu(self.maxPooling_layer(x))
        # print(x.shape)
        x = self.conv_layer2 (x)
        # print(x.shape)
        x = F.relu(self.maxPooling_layer(x))
        # print(x.shape)
        x = x.view(batch_size,-1) #flatten
        # print(x.shape)
        x = self.fc(x) #做交叉熵损失，最后一层不做激活       
        return x
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
model = Net().to(device)

criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=1e-3,momentum=0.5)
# Out:
# cuda:0

# %%
def train(rpoch):
    running_loss= 0.0
    for batch_idx,data in enumerate(train_loader,0):
        inputs,target = data
        inputs = inputs.to(device)
        target = target.to(device)
        optimizer.zero_grad() #优化器清零
        outputs = model(inputs)
        loss = criterion(outputs, target)
        loss.backward() 
        optimizer.step()
        running_loss += loss.item()
        if batch_idx %300 ==0:
            print('[%d,%5d] loss : %.3f' % (epoch, batch_idx, running_loss/300))
            running_loss = 0 

def test():
    correct =0
    total = 0
    with torch.no_grad():
        for data in test_loader:
            images,labels = data
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _,predicted = torch.max(outputs.data,dim = 1 ) #dim=0 :row
            total += labels.size(0)
            correct+= (predicted==labels).sum().item()
    print('acc = ',(100 * correct)/total)

# %%
def show_images(images, labels , pred, nrows=4, ncols=4):
    """
    显示一个批次的图片和标签
    Args:
        images: torch.Tensor, 形状 [batch, 1, 28, 28]
        labels: torch.Tensor, 形状 [batch]
        nrows: 显示的行数
        ncols: 显示的列数
    """
    plt.figure(figsize=(12, 6))
    for i in range(nrows * ncols):
        plt.subplot(nrows, ncols, i+1)
        img = images[i].squeeze().cpu().numpy()  # 去掉通道维度 -> [28, 28]
        plt.imshow(img, cmap='gray')
        if labels[i].item()==pred[i].item():
            plt.title(f"✔ ,Label: {labels[i].item()}")
        else:
            plt.title(f" X ,Label: {labels[i].item()}, Pred: {pred[i].item()}")
        
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
if __name__ == '__main__':
    for epoch in range(100000):
        train(epoch)
        test()
        if epoch % 100 ==0:
            with torch.no_grad():
                for data in test_loader:
                    images,labels = data
                    images = images.to(device)
                    labels = labels.to(device)
                    outputs = model(images)
                    _,predicted = torch.max(outputs.data,dim = 1 ) #dim=0 :row
                    # print(predicted)
                    show_images(images,labels,predicted)
                    break
# Out:
# [0,    0] loss : 0.008
# [0,  300] loss : 2.183
# [0,  600] loss : 1.304
# [0,  900] loss : 0.558
# acc =  88.6
# [1,    0] loss : 0.002
# [1,  300] loss : 0.397
# [1,  600] loss : 0.348
# [1,  900] loss : 0.299
# acc =  91.92
# [2,    0] loss : 0.001
# [2,  300] loss : 0.280
# [2,  600] loss : 0.247
# [2,  900] loss : 0.250
# acc =  93.82
# [3,    0] loss : 0.001
# [3,  300] loss : 0.224
# [3,  600] loss : 0.215
# [3,  900] loss : 0.202
# acc =  94.95
# [4,    0] loss : 0.000
# [4,  300] loss : 0.188
# [4,  600] loss : 0.184
# [4,  900] loss : 0.179
# acc =  95.61
# [5,    0] loss : 0.001
# [5,  300] loss : 0.172
# [5,  600] loss : 0.159
# [5,  900] loss : 0.155
# acc =  95.98
# [6,    0] loss : 0.001
# [6,  300] loss : 0.151
# [6,  600] loss : 0.144
# [6,  900] loss : 0.134
# acc =  96.44
# [7,    0] loss : 0.000
# [7,  300] loss : 0.129
# [7,  600] loss : 0.135
# [7,  900] loss : 0.134
# acc =  96.71
# [8,    0] loss : 0.001
# [8,  300] loss : 0.123
# [8,  600] loss : 0.123
# [8,  900] loss : 0.119
# acc =  96.63
# [9,    0] loss : 0.001
# [9,  300] loss : 0.118
# [9,  600] loss : 0.112
# [9,  900] loss : 0.110
# acc =  97.15
# [10,    0] loss : 0.001
# [10,  300] loss : 0.111
# [10,  600] loss : 0.103
# [10,  900] loss : 0.104
# acc =  97.33
# [11,    0] loss : 0.000
# [11,  300] loss : 0.103
# [11,  600] loss : 0.100
# [11,  900] loss : 0.098
# acc =  97.45
# [12,    0] loss : 0.001
# [12,  300] loss : 0.092
# [12,  600] loss : 0.095
# [12,  900] loss : 0.098
# acc =  98.77
# [121,    0] loss : 0.000
# [121,  300] loss : 0.021
# [121,  600] loss : 0.028
# [121,  900] loss : 0.025
# acc =  98.76
# [122,    0] loss : 0.000
# [122,  300] loss : 0.026
# [122,  600] loss : 0.024
# [122,  900] loss : 0.023
# acc =  98.75
# [123,    0] loss : 0.000
# [123,  300] loss : 0.024
# [123,  600] loss : 0.025
# [123,  900] loss : 0.024
# acc =  98.76
# [124,    0] loss : 0.000
# [124,  300] loss : 0.024
# [124,  600] loss : 0.023
# [124,  900] loss : 0.025
# acc =  98.73
# [125,    0] loss : 0.000
# [125,  300] loss : 0.023
# [125,  600] loss : 0.026
# [125,  900] loss : 0.023
# acc =  98.71
# [126,    0] loss : 0.000
# [126,  300] loss : 0.021
# [126,  600] loss : 0.024
# [126,  900] loss : 0.026
# acc =  98.72
# [127,    0] loss : 0.000
# [127,  300] loss : 0.023
# [127,  600] loss : 0.025
# [127,  900] loss : 0.021
# acc =  98.88
# [128,    0] loss : 0.000
# [128,  300] loss : 0.021
# [128,  600] loss : 0.025
# [128,  900] loss : 0.024
# acc =  98.81
# [129,    0] loss : 0.000
# [129,  300] loss : 0.024
# [129,  600] loss : 0.023
# [129,  900] loss : 0.023
# acc =  98.81
# [130,    0] loss : 0.000
# [130,  300] loss : 0.023
# [130,  600] loss : 0.024
# [130,  900] loss : 0.023
# acc =  98.71
# [131,    0] loss : 0.000
# [131,  300] loss : 0.024
# [131,  600] loss : 0.023
# [131,  900] loss : 0.022
# acc =  98.78
# [132,    0] loss : 0.000
# [132,  300] loss : 0.022
# [132,  600] loss : 0.023
# [132,  900] loss : 0.023
# acc =  98.8
# [133,    0] loss : 0.000
# [133,  300] loss : 0.020
# [133,  600] loss : 0.026
# [133,  900] loss : 0.022
# acc =  98.78
# [134,    0] loss : 0.000
# [134,  300] loss : 0.022
# [134,  600] loss : 0.023
# [134,  900] loss : 0.023
# acc =  98.8
# [135,    0] loss : 0.000
# [135,  300] loss : 0.024
# [135,  600] loss : 0.020
# [135,  900] loss : 0.023
# acc =  98.81
# [136,    0] loss : 0.000
# [136,  300] loss : 0.024
# [136,  600] loss : 0.023
# [136,  900] loss : 0.020
# acc =  98.76
# [137,    0] loss : 0.000
# [137,  300] loss : 0.025
# [137,  600] loss : 0.022
# [137,  900] loss : 0.020
# acc =  98.81
# [138,    0] loss : 0.000
# [138,  300] loss : 0.024
# [138,  600] loss : 0.022
# [138,  900] loss : 0.020
# acc =  98.79
# [139,    0] loss : 0.000
# [139,  300] loss : 0.020
# [139,  600] loss : 0.021
# [139,  900] loss : 0.025
# acc =  98.73
# [140,    0] loss : 0.000
# [140,  300] loss : 0.021
# [140,  600] loss : 0.022
# [140,  900] loss : 0.022
# acc =  98.74
# [141,    0] loss : 0.000
# [141,  300] loss : 0.023
# [141,  600] loss : 0.022
# [141,  900] loss : 0.020
# acc =  98.83
# [142,    0] loss : 0.000
# [142,  300] loss : 0.020
# [142,  600] loss : 0.022
# [142,  900] loss : 0.021
# acc =  98.74
# [143,    0] loss : 0.000
# [143,  300] loss : 0.020
# [143,  600] loss : 0.024
# [143,  900] loss : 0.019
# acc =  98.7
# [144,    0] loss : 0.000
# [144,  300] loss : 0.021
# [144,  600] loss : 0.022
# [144,  900] loss : 0.021
# acc =  98.71
# [145,    0] loss : 0.000
# [145,  300] loss : 0.020
# [145,  600] loss : 0.022
# [145,  900] loss : 0.022
# acc =  98.79
# [146,    0] loss : 0.000
# [146,  300] loss : 0.021
# [146,  600] loss : 0.022
# [146,  900] loss : 0.020
# acc =  98.79
# [147,    0] loss : 0.000
# [147,  300] loss : 0.019
# [147,  600] loss : 0.022
# [147,  900] loss : 0.019
# acc =  98.67
# [148,    0] loss : 0.000
# [148,  300] loss : 0.022
# [148,  600] loss : 0.019
# [148,  900] loss : 0.021
# acc =  98.82
# [149,    0] loss : 0.000
# [149,  300] loss : 0.020
# [149,  600] loss : 0.020
# [149,  900] loss : 0.021
# acc =  98.73
# [150,    0] loss : 0.000
# [150,  300] loss : 0.019
# [150,  600] loss : 0.021
# [150,  900] loss : 0.022
# acc =  98.69
# [151,    0] loss : 0.000
# [151,  300] loss : 0.020
# [151,  600] loss : 0.022
# [151,  900] loss : 0.020
# acc =  98.8
# [152,    0] loss : 0.000
# [152,  300] loss : 0.019
# [152,  600] loss : 0.019
# [152,  900] loss : 0.022
# acc =  98.77
# [153,    0] loss : 0.000
# [153,  300] loss : 0.020
# [153,  600] loss : 0.019
# [153,  900] loss : 0.020
# acc =  98.75
# [154,    0] loss : 0.000
# [154,  300] loss : 0.019
# [154,  600] loss : 0.020
# [154,  900] loss : 0.020
# acc =  98.81
# [155,    0] loss : 0.000
# [155,  300] loss : 0.018
# [155,  600] loss : 0.020
# [155,  900] loss : 0.022
# acc =  98.71
# [156,    0] loss : 0.000
# [156,  300] loss : 0.020
# [156,  600] loss : 0.020
# [156,  900] loss : 0.019
# acc =  98.8
# [157,    0] loss : 0.000
# [157,  300] loss : 0.020
# [157,  600] loss : 0.020
# [157,  900] loss : 0.019
# acc =  98.8
# [158,    0] loss : 0.000
# [158,  300] loss : 0.020
# [158,  600] loss : 0.020
# [158,  900] loss : 0.018
# acc =  98.72
# [159,    0] loss : 0.000
# [159,  300] loss : 0.020
# [159,  600] loss : 0.018
# [159,  900] loss : 0.020
# acc =  98.65
# [160,    0] loss : 0.000
# [160,  300] loss : 0.018
# [160,  600] loss : 0.018
# [160,  900] loss : 0.019
# acc =  98.76
# [161,    0] loss : 0.000
# [161,  300] loss : 0.020
# [161,  600] loss : 0.018
# [161,  900] loss : 0.020
# acc =  98.72
# [162,    0] loss : 0.000
# [162,  300] loss : 0.019
# [162,  600] loss : 0.018
# [162,  900] loss : 0.020
# acc =  98.75
# [163,    0] loss : 0.000
# [163,  300] loss : 0.019
# [163,  600] loss : 0.016
# [163,  900] loss : 0.021
# acc =  98.74
# [185,  900] loss : 0.017
# acc =  98.84
# [186,    0] loss : 0.000
# [186,  300] loss : 0.017
# [186,  600] loss : 0.016
# [186,  900] loss : 0.016
# acc =  98.79
# [187,    0] loss : 0.000
# [187,  300] loss : 0.016
# [187,  600] loss : 0.017
# [187,  900] loss : 0.017
# acc =  98.86
# [188,    0] loss : 0.000
# [188,  300] loss : 0.015
# [188,  600] loss : 0.016
# [188,  900] loss : 0.018
# acc =  98.74
# [189,    0] loss : 0.000
# [189,  300] loss : 0.014
# [189,  600] loss : 0.016
# [189,  900] loss : 0.017
# acc =  98.66
# [190,    0] loss : 0.000
# [190,  300] loss : 0.018
# [190,  600] loss : 0.015
# [190,  900] loss : 0.016
# acc =  98.81
# [191,    0] loss : 0.000
# [191,  300] loss : 0.015
# [191,  600] loss : 0.016
# [191,  900] loss : 0.017
# acc =  98.78
# [192,    0] loss : 0.000
# [192,  300] loss : 0.017
# [192,  600] loss : 0.015
# [192,  900] loss : 0.016
# acc =  98.76
# [193,    0] loss : 0.000
# [193,  300] loss : 0.016
# [193,  600] loss : 0.015
# [193,  900] loss : 0.015
# acc =  98.75
# [194,    0] loss : 0.000
# [194,  300] loss : 0.017
# [194,  600] loss : 0.015
# [194,  900] loss : 0.015
# acc =  98.82
# [195,    0] loss : 0.000
# [195,  300] loss : 0.018
# [195,  600] loss : 0.015
# [195,  900] loss : 0.014
# acc =  98.84
# [196,    0] loss : 0.000
# [196,  300] loss : 0.014
# [196,  600] loss : 0.017
# [196,  900] loss : 0.015
# acc =  98.77
# [197,    0] loss : 0.000
# [197,  300] loss : 0.016
# [197,  600] loss : 0.016
# [197,  900] loss : 0.014
# acc =  98.85
# [198,    0] loss : 0.000
# [198,  300] loss : 0.015
# [198,  600] loss : 0.016
# [198,  900] loss : 0.014
# acc =  98.84
# [199,    0] loss : 0.000
# [199,  300] loss : 0.014
# [199,  600] loss : 0.015
# [199,  900] loss : 0.015
# acc =  98.74
# [200,    0] loss : 0.000
# [200,  300] loss : 0.016
# [200,  600] loss : 0.016
# [200,  900] loss : 0.014
# acc =  98.75
# [201,    0] loss : 0.000
# [201,  300] loss : 0.015
# [201,  600] loss : 0.014
# [201,  900] loss : 0.016
# acc =  98.84
# [202,    0] loss : 0.000
# [202,  300] loss : 0.016
# [202,  600] loss : 0.015
# [202,  900] loss : 0.014
# acc =  98.78
# [203,    0] loss : 0.000
# [203,  300] loss : 0.014
# [203,  600] loss : 0.015
# [203,  900] loss : 0.016
# acc =  98.75
# [204,    0] loss : 0.000
# [204,  300] loss : 0.015
# [204,  600] loss : 0.014
# [204,  900] loss : 0.015
# acc =  98.69
# [205,    0] loss : 0.000
# [205,  300] loss : 0.014
# [205,  600] loss : 0.016
# [205,  900] loss : 0.014
# acc =  98.8
# [206,    0] loss : 0.000
# [206,  300] loss : 0.015
# [206,  600] loss : 0.015
# [206,  900] loss : 0.014
# acc =  98.77
# [207,    0] loss : 0.000
# [207,  300] loss : 0.014
# [207,  600] loss : 0.014
# [207,  900] loss : 0.015
# acc =  98.86
# [208,    0] loss : 0.000
# [208,  300] loss : 0.014
# [208,  600] loss : 0.015
# [208,  900] loss : 0.014
# acc =  98.79
# [209,    0] loss : 0.000
# [209,  300] loss : 0.014
# [209,  600] loss : 0.015
# [209,  900] loss : 0.016
# acc =  98.84
# [210,    0] loss : 0.000
# [210,  300] loss : 0.014
# [210,  600] loss : 0.013
# [210,  900] loss : 0.015
# acc =  98.72
# [211,    0] loss : 0.000
# [211,  300] loss : 0.015
# [211,  600] loss : 0.014
# [211,  900] loss : 0.014
# acc =  98.78
# [212,    0] loss : 0.000
# [212,  300] loss : 0.016
# [212,  600] loss : 0.012
# [212,  900] loss : 0.014
# acc =  98.83
# [213,    0] loss : 0.000
# [213,  300] loss : 0.012
# [213,  600] loss : 0.015
# [213,  900] loss : 0.015
# acc =  98.78
# [214,    0] loss : 0.000
# [214,  300] loss : 0.014
# [214,  600] loss : 0.016
# [214,  900] loss : 0.013
# acc =  98.82
# [215,    0] loss : 0.000
# [215,  300] loss : 0.011
# [215,  600] loss : 0.015
# [215,  900] loss : 0.016
# acc =  98.86
# [216,    0] loss : 0.000
# [216,  300] loss : 0.013
# [216,  600] loss : 0.014
# [216,  900] loss : 0.014
# acc =  98.74
# [217,    0] loss : 0.000
# [217,  300] loss : 0.014
# [217,  600] loss : 0.014
# [217,  900] loss : 0.013
# acc =  98.74
# [218,    0] loss : 0.000
# [218,  300] loss : 0.015
# [218,  600] loss : 0.014
# [218,  900] loss : 0.013
# acc =  98.79
# [219,    0] loss : 0.000
# [219,  300] loss : 0.012
# [219,  600] loss : 0.014
# [219,  900] loss : 0.014
# acc =  98.74
# [220,    0] loss : 0.000
# [220,  300] loss : 0.013
# [220,  600] loss : 0.012
# [220,  900] loss : 0.015
# acc =  98.76
# [221,    0] loss : 0.000
# [221,  300] loss : 0.012
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 if __name__ == '__main__':
#       2     for epoch in range(100000):
# ----> 3         train(epoch)
#       4         test()
#       5         if epoch % 100 ==0:
#
# Cell In[6], line 3, in train(rpoch)
#       1 def train(rpoch):
#       2     running_loss= 0.0
# ----> 3     for batch_idx,data in enumerate(train_loader,0):
#       4         inputs,target = data
#       5         inputs = inputs.to(device)
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\torch\utils\data\dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\torch\utils\data\dataloader.py:671, in _SingleProcessDataLoaderIter._next_data(self)
#     669 def _next_data(self):
#     670     index = self._next_index()  # may raise StopIteration
# --> 671     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672     if self._pin_memory:
#     673         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\torch\utils\data\_utils\fetch.py:58, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\torch\utils\data\_utils\fetch.py:58, in <listcomp>(.0)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\torchvision\datasets\mnist.py:145, in MNIST.__getitem__(self, index)
#     142 img = Image.fromarray(img.numpy(), mode="L")
#     144 if self.transform is not None:
# --> 145     img = self.transform(img)
#     147 if self.target_transform is not None:
#     148     target = self.target_transform(target)
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\torchvision\transforms\transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\torchvision\transforms\transforms.py:270, in Normalize.forward(self, tensor)
#     262 def forward(self, tensor: Tensor) -> Tensor:
#     263     """
#     264     Args:
#     265         tensor (Tensor): Tensor image to be normalized.
#    (...)
#     268         Tensor: Normalized Tensor image.
#     269     """
# --> 270     return F.normalize(tensor, self.mean, self.std, self.inplace)
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\torchvision\transforms\functional.py:360, in normalize(tensor, mean, std, inplace)
#     357 if not isinstance(tensor, torch.Tensor):
#     358     raise TypeError(f"img should be Tensor Image. Got {type(tensor)}")
# --> 360 return F_t.normalize(tensor, mean=mean, std=std, inplace=inplace)
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\torchvision\transforms\functional_tensor.py:934, in normalize(tensor, mean, std, inplace)
#     932 mean = torch.as_tensor(mean, dtype=dtype, device=tensor.device)
#     933 std = torch.as_tensor(std, dtype=dtype, device=tensor.device)
# --> 934 if (std == 0).any():
#     935     raise ValueError(f"std evaluated to zero after conversion to {dtype}, leading to division by zero.")
#     936 if mean.ndim == 1:
#
# KeyboardInterrupt:

# %%
with torch.no_grad():
    for data in test_loader:
        images,labels = data
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _,predicted = torch.max(outputs.data,dim = 1 ) #dim=0 :row
        # print(predicted)
        show_images(images,labels,predicted)
        # break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 9
#       7 _,predicted = torch.max(outputs.data,dim = 1 ) #dim=0 :row
#       8 # print(predicted)
# ----> 9 show_images(images,labels,predicted)
#
# Cell In[20], line 12, in show_images(images, labels, pred, nrows, ncols)
#      10 plt.figure(figsize=(12, 6))
#      11 for i in range(nrows * ncols):
# ---> 12     plt.subplot(nrows, ncols, i+1)
#      13     img = images[i].squeeze().cpu().numpy()  # 去掉通道维度 -> [28, 28]
#      14     plt.imshow(img, cmap='gray')
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\matplotlib\pyplot.py:1338, in subplot(*args, **kwargs)
#    1335             break
#    1336 else:
#    1337     # we have exhausted the known Axes and none match, make a new one!
# -> 1338     ax = fig.add_subplot(*args, **kwargs)
#    1340 fig.sca(ax)
#    1342 axes_to_delete = [other for other in fig.axes
#    1343                   if other != ax and ax.bbox.fully_overlaps(other.bbox)]
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\matplotlib\figure.py:768, in FigureBase.add_subplot(self, *args, **kwargs)
#     765         args = tuple(map(int, str(args[0])))
#     766     projection_class, pkw = self._process_projection_requirements(
#     767         *args, **kwargs)
# --> 768     ax = projection_class(self, *args, **pkw)
#     769     key = (projection_class, pkw)
#     770 return self._add_axes_internal(ax, key)
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\matplotlib\axes\_base.py:675, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     672 self.spines = mspines.Spines.from_dict(self._gen_axes_spines())
#     674 # this call may differ for non-sep axes, e.g., polar
# --> 675 self._init_axis()
#     676 if facecolor is None:
#     677     facecolor = mpl.rcParams['axes.facecolor']
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\matplotlib\axes\_base.py:825, in _AxesBase._init_axis(self)
#     823 self.yaxis = maxis.YAxis(self)
#     824 self.spines.left.register_axis(self.yaxis)
# --> 825 self.spines.right.register_axis(self.yaxis)
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\matplotlib\spines.py:218, in Spine.register_axis(self, axis)
#     216 self.axis = axis
#     217 if self.axis is not None:
# --> 218     self.axis.clear()
#     219 self.stale = True
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\matplotlib\axis.py:891, in Axis.clear(self)
#     887 self.labelpad = mpl.rcParams['axes.labelpad']
#     889 self._init()
# --> 891 self._set_scale('linear')
#     893 # Clear the callback registry for this axis, or it may "leak"
#     894 self.callbacks = cbook.CallbackRegistry(signals=["units"])
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\matplotlib\axis.py:782, in Axis._set_scale(self, value, **kwargs)
#     780 else:
#     781     self._scale = value
# --> 782 self._scale.set_default_locators_and_formatters(self)
#     784 self.isDefault_majloc = True
#     785 self.isDefault_minloc = True
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\matplotlib\scale.py:105, in LinearScale.set_default_locators_and_formatters(self, axis)
#     103 def set_default_locators_and_formatters(self, axis):
#     104     # docstring inherited
# --> 105     axis.set_major_locator(AutoLocator())
#     106     axis.set_major_formatter(ScalarFormatter())
#     107     axis.set_minor_formatter(NullFormatter())
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\matplotlib\ticker.py:2900, in AutoLocator.__init__(self)
#    2898     nbins = 'auto'
#    2899     steps = [1, 2, 2.5, 5, 10]
# -> 2900 super().__init__(nbins=nbins, steps=steps)
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\matplotlib\ticker.py:2008, in MaxNLocator.__init__(self, nbins, **kwargs)
#    2006 if nbins is not None:
#    2007     kwargs['nbins'] = nbins
# -> 2008 self.set_params(**{**self.default_params, **kwargs})
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\matplotlib\ticker.py:2068, in MaxNLocator.set_params(self, **kwargs)
#    2066     else:
#    2067         self._steps = self._validate_steps(steps)
# -> 2068     self._extended_steps = self._staircase(self._steps)
#    2069 if 'integer' in kwargs:
#    2070     self._integer = kwargs.pop('integer')
#
# File D:\Anaconda\envs\torch_gpu\lib\site-packages\matplotlib\ticker.py:2029, in MaxNLocator._staircase(steps)
#    2025 @staticmethod
#    2026 def _staircase(steps):
#    2027     # Make an extended staircase within which the needed step will be
#    2028     # found.  This is probably much larger than necessary.
# -> 2029     return np.concatenate([0.1 * steps[:-1], steps, [10 * steps[1]]])
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:
